# %%
import numpy as np
import pandas as pd
import pickle
from datetime import date
from IPython.display import clear_output

from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %load_ext autoreload
# %autoreload 2

# %%
df_videos_cleaned_v9 = pickle.load(open('../Data/df_videos_cleaned_v9.pickle', 'rb'))

# %% [markdown]
# ### All the functions (Need to put these into a separate .py file)

# %%
def initial_recommender(df):
    '''
    Input: Final dataframe of video data, user input on topic, duration, and upload date
    Output: Top five recommendations
    '''
    ## Take user inputs
    print('Which topics would you like to learn about?')
    topic = input().title()
    
    print('\n')
    print('What is the upper limit of the duration of videos (in minutes)?')
    duration = int(input())
    
    print('\n')
    print('How recent do you want the videos to be (in months since upload date)?')
    upload_date = int(input())
    today = date.today()
    df['Months Since Upload'] = df['Upload Date'].apply(lambda x:((today - x).days)*12/365)

    clear_output()
    
    ## Define a new variable to store the preferred videos. Copy the contents of df to filtered videos
    df_videos_filtered = df.copy()

    ## Return top five videos based on topic coefficient (how relevant the videos are to the user's topic)
    df_videos_filtered = df_videos_filtered[(df_videos_filtered['Topic']==topic) & 
                                      (df_videos_filtered['Duration']<duration) &
                                      (df_videos_filtered['Months Since Upload']<upload_date)]
    df_videos_filtered = df_videos_filtered.sort_values('Topic Coefficient', ascending=False)
    
    return df_videos_filtered.head(), df_videos_filtered

# %%
def follow_up_recommender(video_id, df_videos_filtered, vectorizer, similarity_metric):
    '''
    Input: Video ID of a user's liked video, and the dataframe of the filtered videos generated from the initial recommender
    Output: Top five follow-up recommendations using content-based recommender system
    '''
    ## Fit and transform the transcript into a document-term matrix
    word_list = [[word[0] for word in doc] for doc in df_videos_filtered['Transcript']]
    vec = vectorizer(tokenizer=lambda doc:doc, lowercase=False)
    matrix = vec.fit_transform(word_list).toarray()
    
    ## Generate a similarity matrix
    similarity_matrix = similarity_metric(matrix, matrix)
    
    ## Create a series of indices for the videos (rows)  
    df_videos_filtered = df_videos_filtered.reset_index(drop=True)
    indices = pd.Series(df_videos_filtered['Video_ID'])
    
    ## Get the index of the user's liked video
    idx = indices[indices == video_id].index[0]
    
    ## Create a series with the similarity scores in descending order and grab indices
    score_series = pd.Series(similarity_matrix[idx]).sort_values(ascending=False)
    similarity_indices = list(score_series.index)
    
    ## Drop videos that were in the original recommendation
    similarity_indices = [index for index in similarity_indices if index not in list(df_videos_filtered[:5].index)]
    top_5_indices = similarity_indices[:5]
    
    ## Populate a dataframe of the recommended videos
    df_videos_follow_up_recs = df_videos_filtered.iloc[top_5_indices]
    
    return df_videos_follow_up_recs

# %% [markdown]
# ### Initial knowledge-based recommender

# %%
df_videos_recs_test1, df_videos_filtered_test1 = initial_recommender(df_videos_cleaned_v9)

# %%
df_videos_recs_test1
# Out:
#          Video_ID                                              Title  \
# 893   2jLngtFzh8I  Pomp Podcast #412: Peter Doyle on Modern Value...
# 1155  Z52LyI9j1rI          TIP332: Long-Term Investing w/ Tom Gayner
# 989   X-3KpqHr_kY        Is Warren Buffett's 'Value Investing' Dead?
# 1237  mR_iGHZ91AY  Long Term Investing vs Momentum Trading in the...
# 855   Iv0zmTmKHYg                 Value Investing I: The Back Story!
#
#      Upload Date   Duration         Views Number of Likes  \
# 893   2020-10-21   4.666667   8,710 views             239
# 1155  2021-01-18   2.750000   3,127 views             100
# 989   2020-06-03   4.666667  32,316 views             865
# 1237  2020-04-15   1.050000   9,508 views             222
# 855   2020-10-23  19.850000  24,518 views             846
#
#                                             Description  \
# 893   This is an episode of The Pomp Podcast with ho...
# 1155  In today’s episode, we sit down with legendary...
# 989   Is value investing dead? Ben Graham, and now W...
# 1237  The stock market has fallen, and bounced. It's...
# 855   Many investors, when asked to describe their i...
#
#                                              Transcript    Topic  \
# 893   [(right, INTJ), (bang, NOUN), (bang, NOUN), (s...  General
# 1155  [(listen, VERB), (tip, NOUN), (today, NOUN), (...  General
# 989   [(hey, INTJ), (welcome, NOUN), (channel, NOUN)...  General
# 1237  [(hey, INTJ), (welcome, NOUN), (channel, NOUN)...  General
# 855   [(hi, INTJ), (welcome, ADJ), (session, NOUN), ...  General
#
#       Topic Coefficient  Months Since Upload
# 893               0.113             4.701370
# 1155              0.112             1.775342
# 989               0.105             9.304110
# 1237              0.102            10.915068
# 855               0.102             4.635616

# %%
df_videos_cleaned_v9.to_csv('../App/df_videos_cleaned_v9.csv',index=False)

# %% [markdown]
# ### Follow-up content-based recommender (after the initial knowledge-based recommender takes care of the cold start problem)

# %% [markdown]
# #### TfidfVectorizer, Cosine similarity

# %%
X_tfidf_cosine = follow_up_recommender('X-3KpqHr_kY', df_videos_filtered_test1, TfidfVectorizer, cosine_similarity)
X_tfidf_cosine
# Out:
#        Video_ID                                              Title  \
# 92  LaGhq3xNUpk         Growth Vs Value Investing | WHICH IS BEST?
# 67  2GFwfNOKWJM  Value Investing Proper Definition - Is Value I...
# 10  IxbgNEfNRvc                    Value Investing is Dead in 2020
# 20  VbTX_WQaYkU                            What is Value Investing
# 41  y1bXFsUtgjk                                    Value Investing
#
#    Upload Date   Duration         Views Number of Likes  \
# 92  2021-02-28   6.950000      45 views               7
# 67  2020-11-14  15.666667  30,879 views            1.4K
# 10  2020-10-16  17.550000  13,346 views             691
# 20  2020-09-07  14.783333     262 views              20
# 41  2021-02-21   8.450000      81 views               6
#
#                                           Description  \
# 92  A lot of people like myself wonder, what's bet...
# 67  Is Value Investing, Dead Or Alive, Something F...
# 10  In this video I breakdown whether or not Value...
# 20  What is Value Investing?\n\n🔬Join my INVESTMEN...
# 41  Have you ever heard of Warren Buffett ? He’s w...
#
#                                            Transcript    Topic  \
# 92  [(growth, NOUN), (versus, ADP), (value, NOUN),...  General
# 67  [(good, ADJ), (day, NOUN), (fell, VERB), (inve...  General
# 10  [(hey, INTJ), (welcome, INTJ), (create, VERB),...  General
# 20  [(video, PROPN), (value, NOUN), (invest, VERB)...  General
# 41  [(music, NOUN), (hey, INTJ), (today, NOUN), (t...  General
#
#     Topic Coefficient  Months Since Upload
# 92              0.063             0.427397
# 67              0.069             3.912329
# 10              0.095             4.865753
# 20              0.086             6.147945
# 41              0.077             0.657534

# %% [markdown]
# #### TfidfVectorizer, Euclidean distance

# %%
X_tfidf_euclidean = follow_up_recommender('X-3KpqHr_kY', df_videos_filtered_test1, TfidfVectorizer, euclidean_distances)
X_tfidf_euclidean
# Out:
#         Video_ID                                              Title  \
# 278  IhNXFgfLnl0  How to Select Best Stocks for long Term Invest...
# 277  1q0ifWYGRzQ  how to do fundamental analysis of stock | Basi...
# 276  D4wdMRvRZE4  Stock valuation Problem / Without loss | Malay...
# 282  86QNcnrEpak     How to Pick Stock Like Warren Buffet in Hindi?
# 283  eUbP-yBKK7U  My Growth Portfolio | 0$ - 100K Investing Goal...
#
#     Upload Date   Duration        Views Number of Likes  \
# 278  2021-01-01   8.333333  4,341 views             256
# 277  2020-08-31  14.816667    181 views              10
# 276  2020-11-14  12.283333    160 views              13
# 282  2020-05-18  11.333333    431 views              17
# 283  2021-02-26  13.550000    967 views              38
#
#                                            Description  \
# 278  📊 | Tamil Stock Market | \n\n🎯 OPEN ZERODHA DE...
# 277  Hi this video is about\n\nhow to do fundamenta...
# 276  You want to see this for being able to solve p...
# 282  this video provide the information about how w...
# 283  Investing in US and Canadian stock market | My...
#
#                                             Transcript    Topic  \
# 278                    [(foreign, ADJ), (thank, VERB)]  General
# 277  [(foreign, ADJ), (foreign, ADJ), (foreign, ADJ...  General
# 276  [(music, NOUN), (foreign, ADJ), (music, NOUN),...  General
# 282  [(music, NOUN), (music, NOUN), (music, NOUN), ...  General
# 283  [(music, NOUN), (music, NOUN), (music, NOUN), ...  General
#
#      Topic Coefficient  Months Since Upload
# 278              0.009             2.334247
# 277              0.009             6.378082
# 276              0.010             3.912329
# 282              0.009             9.830137
# 283              0.009             0.493151

# %% [markdown]
# #### CountVectorizer, Cosine similarity

# %%
X_cv_cosine = follow_up_recommender('X-3KpqHr_kY', df_videos_filtered_test1, CountVectorizer, cosine_similarity)
X_cv_cosine
# Out:
#        Video_ID                                              Title  \
# 63  Jf_XvpYTDSA  Best Way Of Investing: Value Vs Growth | Bill ...
# 20  VbTX_WQaYkU                            What is Value Investing
# 92  LaGhq3xNUpk         Growth Vs Value Investing | WHICH IS BEST?
# 25  lcqW9pKeZVs  Why Value Investing is outdated? Warren Buffet...
# 10  IxbgNEfNRvc                    Value Investing is Dead in 2020
#
#    Upload Date   Duration         Views Number of Likes  \
# 63  2020-09-04  13.800000   1,365 views              24
# 20  2020-09-07  14.783333     262 views              20
# 92  2021-02-28   6.950000      45 views               7
# 25  2020-05-08  12.166667  66,643 views            5.9K
# 10  2020-10-16  17.550000  13,346 views             691
#
#                                           Description  \
# 63  On this segment, ET NOW’s Ajaya Sharma is in c...
# 20  What is Value Investing?\n\n🔬Join my INVESTMEN...
# 92  A lot of people like myself wonder, what's bet...
# 25  Warren Buffett just had his Berkshire Hathaway...
# 10  In this video I breakdown whether or not Value...
#
#                                            Transcript    Topic  \
# 63  [(know, VERB), (big, ADJ), (cut, NOUN), (come,...  General
# 20  [(video, PROPN), (value, NOUN), (invest, VERB)...  General
# 92  [(growth, NOUN), (versus, ADP), (value, NOUN),...  General
# 25  [(hi, INTJ), (friend, NOUN), (warren, PROPN), ...  General
# 10  [(hey, INTJ), (welcome, INTJ), (create, VERB),...  General
#
#     Topic Coefficient  Months Since Upload
# 63              0.069             6.246575
# 20              0.086             6.147945
# 92              0.063             0.427397
# 25              0.083            10.158904
# 10              0.095             4.865753

# %% [markdown]
# #### CountVectorizer, Euclidean distance

# %%
X_cv_euclidean = follow_up_recommender('X-3KpqHr_kY', df_videos_filtered_test1, CountVectorizer, euclidean_distances)
X_cv_euclidean
# Out:
#         Video_ID                                              Title  \
# 12   zqgRCerwSfQ  Free Cash Flow Plus Growth: Reverse Engineerin...
# 16   9sWecuhjzOI  My March 2021 BNPL Game Plan For ZIP, Afterpay...
# 73   i5mT4uVFCDI  One of my Long Term Investments ROCKETS 70% | ...
# 128  X_7s1g9Uut0  Top 7 BANK Stocks to Watch! - Q3 Analysis 2020...
# 34   lLx8q0SJkkE  The Best Long Term Trading Strategy (Original ...
#
#     Upload Date   Duration         Views Number of Likes  \
# 12   2020-11-03   5.666667   1,844 views              72
# 16   2021-03-03   2.750000   5,247 views             190
# 73   2021-03-03  17.050000     121 views               8
# 128  2020-09-06   2.016667   9,504 views             700
# 34   2020-08-05   1.050000  27,666 views              1K
#
#                                            Description  \
# 12   QuickFS Link: https://quickfs.net/?via=focused...
# 16   In this video I unpack my March 2021 game plan...
# 73   In this video, I will be talking about my thou...
# 128  What are the top bank stocks to watch in 2020 ...
# 34   For more info contact info@ifundtraders.com. O...
#
#                                             Transcript    Topic  \
# 12   [(music, NOUN), (welcome, ADJ), (welcome, ADJ)...  General
# 16   [(hey, INTJ), (welcome, INTJ), (phil, ADJ), (m...  General
# 73   [(music, NOUN), (welcome, ADJ), (start, NOUN),...  General
# 128  [(long, ADV), (wait, VERB), (finally, ADV), (c...  General
# 34   [(right, ADV), (welcome, INTJ), (welcome, VERB...  General
#
#      Topic Coefficient  Months Since Upload
# 12               0.094             4.273973
# 16               0.088             0.328767
# 73               0.067             0.328767
# 128              0.057             6.180822
# 34               0.079             7.232877

# %% [markdown]
# #### *Conclusion: Using TfidfVectorizer and cosine similarity gives the best recommendations, based on my domain knowledge in stock investing.  Tfidf and CV produce similar results for cosine similarity, but Tfidf gets slightly better results in terms of topic relevance*
