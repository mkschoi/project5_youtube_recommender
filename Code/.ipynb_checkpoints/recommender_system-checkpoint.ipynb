# %%
import numpy as np
import pandas as pd
import pickle
from datetime import date
from IPython.display import clear_output

from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %load_ext autoreload
# %autoreload 2

# %%
df_videos_cleaned_v10 = pickle.load(open('../Data/df_videos_cleaned_v10.pickle', 'rb'))

# %%
df_videos_cleaned_v10
# Out:
#          Video_ID                                              Title  \
# 1083  rtxSDyASUKQ  UNBOXING | The Intelligent Investor: The Defin...
# 94    dBb_pbQwULo  How to select a stock for investing | Introduc...
# 1355  L2ZrCb5hj9w              A GOOD STOCK FOR LONG TERM INVESTMENT
# 970   w96XTaqxltw  Value Investing Guide Singapore | 8 financial ...
# 86    3pGTy3aNGRs  Top 5 reasons why COAL INDIA is Falling | CA R...
# ...           ...                                                ...
# 1769  gqpfvyFl_Jk                             Growth Vs. Value ETFs?
# 1774  4iSh1svBWmA  Is It The End Of Growth Stocks? - Behavioral V...
# 1775  dw9iRBXKqD0  Investors are starting to recognize a lot of E...
# 1776  i8WO9cjlQA0         Should You BUY BUZZ ETF? (High Growth ETF)
# 1777  Nv9YynlfwBw  TOP 3 PENNY STOCKS To BUY NOW with MASSIVE Ups...
#
#      Upload Date   Duration          Views Number of Likes  \
# 1083  2021-03-03   1.466667       11 views               1
# 94    2021-01-20   5.750000       42 views               7
# 1355  2020-07-23  10.666667    7,643 views             391
# 970   2017-09-22   1.100000    1,115 views               9
# 86    2020-10-07   8.900000  193,341 views            9.4K
# ...          ...        ...            ...             ...
# 1769  2019-04-12   3.800000    7,133 views             126
# 1774  2021-01-15   3.233333      264 views            LIKE
# 1775  2021-02-26   4.433333    1,211 views              20
# 1776  2021-03-03   6.950000    5,671 views             115
# 1777  2021-02-28  10.183333    4,079 views             153
#
#                                             Description  \
# 1083  FULL TITLE: The Intelligent Investor: The Defi...
# 94    This video tells you the process of stock sele...
# 1355  UPSTOX FREE DEMAT ACCOUNT (DISCOUNT BROKER)\nh...
# 970   Value Investing Singapore Guide: https://www.d...
# 86    A detailed analysis of the recent developments...
# ...                                                 ...
# 1769  The difference between the two is surprisingly...
# 1774  In 2000, the sign of the investing times was c...
# 1775  #ESGinvesting #climatechange #YahooFinance\nYa...
# 1776  In this video we are looking at the new ETF BU...
# 1777  In this video we will talk about 3 penny stock...
#
#                                              Transcript  \
# 1083  [(music, NOUN), (music, NOUN), (music, NOUN), ...
# 94        [(music, NOUN), (music, NOUN), (music, NOUN)]
# 1355                   [(music, PROPN), (video, PROPN)]
# 970                                     [(music, NOUN)]
# 86    [(coal, NOUN), (extract, NOUN), (ground, NOUN)...
# ...                                                 ...
# 1769  [(welcome, INTJ), (etf, PROPN), (comm, PROPN),...
# 1774  [(end, NOUN), (growth, NOUN), (stock, NOUN), (...
# 1775  [(president, PROPN), (biden, PROPN), (focus, N...
# 1776  [(alrighty, PROPN), (welcome, ADJ), (episode, ...
# 1777  [(warn, VERB), (penny, NOUN), (stock, NOUN), (...
#
#                                    Topic  Topic Coefficient
# 1083                     Value Investing              0.000
# 94    Fundamental Vs. Technical Analysis              0.000
# 1355                 Long-term Investing              0.000
# 970                      Value Investing              0.000
# 86                               General              0.003
# ...                                  ...                ...
# 1769                   Passive Investing              0.087
# 1774             Electric Vehicle Stocks              0.109
# 1775                   Passive Investing              0.027
# 1776                   Passive Investing              0.241
# 1777                   Technology Stocks              0.046
#
# [1777 rows x 10 columns]

# %% [markdown]
# ### All the functions (Need to put these into a separate .py file)

# %%
def initial_recommender(df):
    '''
    Input: Final dataframe of video data, user input on topic, duration, and upload date
    Output: Top five recommendations
    '''
    ## Take user inputs
    print('Which topics would you like to learn about?')
    topic = input().title()
    
    print('\n')
    print('What is the upper limit of the duration of videos (in minutes)?')
    duration = int(input())
    
    print('\n')
    print('How recent do you want the videos to be (in months since upload date)?')
    upload_date = int(input())
    today = date.today()
    df['Months Since Upload'] = df['Upload Date'].apply(lambda x:((today - x).days)*12/365)

    clear_output()
    
    ## Define a new variable to store the preferred videos. Copy the contents of df to filtered videos
    df_videos_filtered = df.copy()

    ## Return top five videos based on topic coefficient (how relevant the videos are to the user's topic)
    df_videos_filtered = df_videos_filtered[(df_videos_filtered['Topic']==topic) & 
                                      (df_videos_filtered['Duration']<duration) &
                                      (df_videos_filtered['Months Since Upload']<upload_date)]
    df_videos_filtered = df_videos_filtered.sort_values('Topic Coefficient', ascending=False)
    
    return df_videos_filtered.head(), df_videos_filtered

# %%
def follow_up_recommender(video_id, df_videos_filtered, vectorizer, similarity_metric):
    '''
    Input: Video ID of a user's liked video, and the dataframe of the filtered videos generated from the initial recommender
    Output: Top five follow-up recommendations using content-based recommender system
    '''
    ## Fit and transform the transcript into a document-term matrix
    word_list = [[word[0] for word in doc] for doc in df_videos_filtered['Transcript']]
    vec = vectorizer(tokenizer=lambda doc:doc, lowercase=False)
    matrix = vec.fit_transform(word_list).toarray()
    
    ## Generate a similarity matrix
    similarity_matrix = similarity_metric(matrix, matrix)
    
    ## Create a series of indices for the videos (rows)  
    df_videos_filtered = df_videos_filtered.reset_index(drop=True)
    indices = pd.Series(df_videos_filtered['Video_ID'])
    
    ## Get the index of the user's liked video
    idx = indices[indices == video_id].index[0]
    
    ## Create a series with the similarity scores in descending order and grab indices
    score_series = pd.Series(similarity_matrix[idx]).sort_values(ascending=False)
    similarity_indices = list(score_series.index)
    
    ## Drop videos that were in the original recommendation
    similarity_indices = [index for index in similarity_indices if index not in list(df_videos_filtered[:5].index)]
    top_5_indices = similarity_indices[:5]
    
    ## Populate a dataframe of the recommended videos
    df_videos_follow_up_recs = df_videos_filtered.iloc[top_5_indices]
    
    return df_videos_follow_up_recs

# %% [markdown]
# ### Initial knowledge-based recommender

# %%
df_videos_recs_test1, df_videos_filtered_test1 = initial_recommender(df_videos_cleaned_v10)

# %%
df_videos_recs_test1
# Out:
#          Video_ID                                              Title  \
# 852   rbd_ylJkD0g  Growth Investing vs Value Investing In 2020 | ...
# 1436  ViNvWPGsfP0  What is a Growth Stock - Growth Stock Explaine...
# 1616  jwBAInK32qU  Growth vs. Value Investing in 2021 (BEST INVES...
# 1661  LaGhq3xNUpk         Growth Vs Value Investing | WHICH IS BEST?
# 1488  MIR3BXUtrak  Why Growth Investing Is Harder Than You Think ...
#
#      Upload Date   Duration        Views Number of Likes  \
# 852   2020-07-20  12.650000    661 views              49
# 1436  2018-06-19   2.750000  8,341 views             171
# 1616  2021-02-07  11.300000     68 views               9
# 1661  2021-02-28   6.950000     45 views               7
# 1488  2020-10-18  19.383333    206 views              12
#
#                                             Description  \
# 852      Invest with eToro:\n\nhttps://etoro.tw/3hcqqdo
# 1436  Growth Stock Investing is investing in a stock...
# 1616  In the investing world, there is a never endin...
# 1661  A lot of people like myself wonder, what's bet...
# 1488  Growth investing has seemed easy in the past d...
#
#                                              Transcript  \
# 852   [(today, NOUN), (talk, VERB), (different, ADJ)...
# 1436  [(growth, NOUN), (stock, NOUN), (stock, NOUN),...
# 1616  [(coke, PROPN), (pepsi, PROPN), (adidas, PROPN...
# 1661  [(growth, NOUN), (versus, ADP), (value, NOUN),...
# 1488  [(welcome, INTJ), (return, NOUN), (focus, NOUN...
#
#                                      Topic  Topic Coefficient  \
# 852   Growth Investing Vs. Value Investing              0.151
# 1436  Growth Investing Vs. Value Investing              0.143
# 1616  Growth Investing Vs. Value Investing              0.108
# 1661  Growth Investing Vs. Value Investing              0.085
# 1488  Growth Investing Vs. Value Investing              0.081
#
#       Months Since Upload
# 852              7.857534
# 1436            32.909589
# 1616             1.216438
# 1661             0.526027
# 1488             4.898630

# %%
df_videos_cleaned_v10.to_csv('../App/df_videos_cleaned_v10.csv',index=False)

# %% [markdown]
# ### Follow-up content-based recommender (after the initial knowledge-based recommender takes care of the cold start problem)

# %% [markdown]
# #### TfidfVectorizer, Cosine similarity

# %%
X_tfidf_cosine = follow_up_recommender('ViNvWPGsfP0', df_videos_filtered_test1, TfidfVectorizer, cosine_similarity)
X_tfidf_cosine
# Out:
#        Video_ID                                              Title  \
# 6   JGJC5wlJTHU  Growth Stocks vs Value Stocks || How to START ...
# 9   cW1Djgz092g  Growth Investing vs Value Investing vs Income ...
# 20  AovFMi0I3_E  R.I.P Value Investing? Value Investing vs Grow...
# 17  RB-CHLDEgkk  Don't Buy Growth Stocks! (WARNING) || The Trut...
# 10  w4BlPd2-Ezw                           What is Growth Investing
#
#    Upload Date   Duration        Views Number of Likes  \
# 6   2020-06-18   7.083333  1,285 views             120
# 9   2018-12-05   8.250000    163 views              12
# 20  2020-06-03  12.450000  3,821 views             250
# 17  2020-08-13   8.033333  3,772 views             224
# 10  2019-04-05   4.016667    454 views               9
#
#                                           Description  \
# 6   Growth Stocks vs Value Stocks || How to START ...
# 9   Today we discuss growth investing vs value inv...
# 20  🔵 Get My FREE Investing Guide! 👉  http://bit.l...
# 17  🔵 Get My FREE Investing Guide! 👉  http://bit.l...
# 10  Growth Investing is an investment strategy tha...
#
#                                            Transcript  \
# 6   [(music, NOUN), (welcome, NOUN), (average, ADJ...
# 9   [(music, PROPN), (brynjar, PROPN), (meal, NOUN...
# 20  [(hi, INTJ), (welcome, INTJ), (invest, VERB), ...
# 17  [(hi, INTJ), (welcome, INTJ), (invest, VERB), ...
# 10  [(music, NOUN), (music, NOUN), (growth, NOUN),...
#
#                                    Topic  Topic Coefficient  \
# 6   Growth Investing Vs. Value Investing              0.079
# 9   Growth Investing Vs. Value Investing              0.069
# 20  Growth Investing Vs. Value Investing              0.046
# 17  Growth Investing Vs. Value Investing              0.052
# 10  Growth Investing Vs. Value Investing              0.067
#
#     Months Since Upload
# 6              8.909589
# 9             27.353425
# 20             9.402740
# 17             7.068493
# 10            23.375342

# %% [markdown]
# #### TfidfVectorizer, Euclidean distance

# %%
X_tfidf_euclidean = follow_up_recommender('ViNvWPGsfP0', df_videos_filtered_test1, TfidfVectorizer, euclidean_distances)
X_tfidf_euclidean
# Out:
#        Video_ID                                              Title  \
# 36  TIlBvMhNXz0  Look for growth opportunities in health care, ...
# 38  v_BK3pj7Cvs  Value Stocks vs. Growth Stocks: Which Way Shou...
# 11  QzLrCQ_yOSo  Jim Rogers Latest interview 2020: Value Vs Gro...
# 19  Zvw8WUaHXgw        Why Does Insight Focus on Growth Investing?
# 24  otx-wAKI_pc  Value Is Seen as More Serious Than Growth Inve...
#
#    Upload Date  Duration        Views Number of Likes  \
# 36  2020-10-22  1.850000  3,836 views              40
# 38  2018-11-29  2.466667  1,750 views              16
# 11  2020-09-25  7.216667    905 views              47
# 19  2019-01-15  1.716667     84 views               0
# 24  2019-07-11  5.866667  4,248 views              48
#
#                                           Description  \
# 36  Doug Sandler, Riverfront Investment Group's he...
# 38  One of the most common nicknames for your reti...
# 11  ⭐ ⭐ DON'T FORGET TO SUBSCRIBE!!!  For More inv...
# 19  Explore Insight Partners' "Scale-Up Hacks" pla...
# 24  Jul.10 -- James Anderson, Baillie Gifford part...
#
#                                            Transcript  \
# 36  [(know, PROPN), (average, ADJ), (return, NOUN)...
# 38  [(robert, PROPN), (brokamp, PROPN), (far, ADV)...
# 11  [(think, VERB), (investor, NOUN), (point, NOUN...
# 19  [(growth, NOUN), (investor, NOUN), (think, VER...
# 24  [(james, PROPN), (honor, NOUN), (guest, NOUN),...
#
#                                    Topic  Topic Coefficient  \
# 36  Growth Investing Vs. Value Investing              0.028
# 38  Growth Investing Vs. Value Investing              0.016
# 11  Growth Investing Vs. Value Investing              0.066
# 19  Growth Investing Vs. Value Investing              0.046
# 24  Growth Investing Vs. Value Investing              0.040
#
#     Months Since Upload
# 36             4.767123
# 38            27.550685
# 11             5.654795
# 19            26.005479
# 24            20.186301

# %% [markdown]
# #### CountVectorizer, Cosine similarity

# %%
X_cv_cosine = follow_up_recommender('ViNvWPGsfP0', df_videos_filtered_test1, CountVectorizer, cosine_similarity)
X_cv_cosine
# Out:
#        Video_ID                                              Title  \
# 9   cW1Djgz092g  Growth Investing vs Value Investing vs Income ...
# 17  RB-CHLDEgkk  Don't Buy Growth Stocks! (WARNING) || The Trut...
# 37  FEL6pUqB34E  Breaking Views: Is Growth Investing Healthier ...
# 8   mVe1oGzKpJw     Value Versus Growth Investing - Which is Best?
# 20  AovFMi0I3_E  R.I.P Value Investing? Value Investing vs Grow...
#
#    Upload Date   Duration         Views Number of Likes  \
# 9   2018-12-05   8.250000     163 views              12
# 17  2020-08-13   8.033333   3,772 views             224
# 37  2020-03-23   2.766667      40 views               0
# 8   2019-09-09   9.166667  11,189 views             461
# 20  2020-06-03  12.450000   3,821 views             250
#
#                                           Description  \
# 9   Today we discuss growth investing vs value inv...
# 17  🔵 Get My FREE Investing Guide! 👉  http://bit.l...
# 37  "You may have noticed that growth stocks are d...
# 8   Value investing usually beats growth investing...
# 20  🔵 Get My FREE Investing Guide! 👉  http://bit.l...
#
#                                            Transcript  \
# 9   [(music, PROPN), (brynjar, PROPN), (meal, NOUN...
# 17  [(hi, INTJ), (welcome, INTJ), (invest, VERB), ...
# 37  [(music, NOUN), (notice, VERB), (growth, NOUN)...
# 8   [(different, ADJ), (style, NOUN), (invest, VER...
# 20  [(hi, INTJ), (welcome, INTJ), (invest, VERB), ...
#
#                                    Topic  Topic Coefficient  \
# 9   Growth Investing Vs. Value Investing              0.069
# 17  Growth Investing Vs. Value Investing              0.052
# 37  Growth Investing Vs. Value Investing              0.025
# 8   Growth Investing Vs. Value Investing              0.071
# 20  Growth Investing Vs. Value Investing              0.046
#
#     Months Since Upload
# 9             27.353425
# 17             7.068493
# 37            11.769863
# 8             18.213699
# 20             9.402740

# %% [markdown]
# #### CountVectorizer, Euclidean distance

# %%
X_cv_euclidean = follow_up_recommender('ViNvWPGsfP0', df_videos_filtered_test1, CountVectorizer, euclidean_distances)
X_cv_euclidean
# Out:
#        Video_ID                                              Title  \
# 14  YGEe9Df2XSs  Best Way to Invest Money: Value Investing vs G...
# 18  NPJgpY6T7lQ  WHAT IS GROWTH INVESTING? | HOW TO SELECT GROW...
# 20  AovFMi0I3_E  R.I.P Value Investing? Value Investing vs Grow...
# 5   jQEaRQyChaM          Growth vs. Value Investing - What's Best?
# 12  dDg6QX_Avu0  Howard Marks on growth investing; says, 'have ...
#
#    Upload Date   Duration         Views Number of Likes  \
# 14  2019-11-21  29.650000  52,819 views            1.7K
# 18  2019-09-10  16.933333   5,017 views             217
# 20  2020-06-03  12.450000   3,821 views             250
# 5   2019-04-23  17.666667     423 views              32
# 12  2021-02-02  19.233333   4,352 views             115
#
#                                           Description  \
# 14  Value vs growth investing is a debate practica...
# 18  STOXKART FREE DEMAT ACCOUNT OPENING (PROMOCODE...
# 20  🔵 Get My FREE Investing Guide! 👉  http://bit.l...
# 5   Growth versus value investing – what’s best?\n...
# 12  Subscribe To ET Now For Latest Updates On Stoc...
#
#                                            Transcript  \
# 14  [(chris, PROPN), (hill, PROPN), (coming, VERB)...
# 18  [(music, NOUN), (applause, NOUN), (music, NOUN...
# 20  [(hi, INTJ), (welcome, INTJ), (invest, VERB), ...
# 5   [(tom, PROPN), (invest, VERB), (tom, PROPN), (...
# 12  [(music, NOUN), (applause, NOUN), (extraordina...
#
#                                    Topic  Topic Coefficient  \
# 14  Growth Investing Vs. Value Investing              0.054
# 18  Growth Investing Vs. Value Investing              0.047
# 20  Growth Investing Vs. Value Investing              0.046
# 5   Growth Investing Vs. Value Investing              0.080
# 12  Growth Investing Vs. Value Investing              0.066
#
#     Months Since Upload
# 14            15.813699
# 18            18.180822
# 20             9.402740
# 5             22.783562
# 12             1.380822

# %% [markdown]
# #### *Conclusion: Using TfidfVectorizer and cosine similarity gives the best recommendations, based on my domain knowledge in stock investing.  Tfidf and CV produce similar results for cosine similarity, but Tfidf gets slightly better results in terms of topic relevance*
