# %%
import preprocessing_utils as pu
import rec_utils as ru
import pickle

from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_videos_cleaned_v10 = pickle.load(open('../Data/df_videos_cleaned_v10.pickle', 'rb')).reset_index(drop=True)

# %% [markdown]
# ### Initial knowledge-based recommender

# %%
df_videos_recs_test1, df_videos_filtered_test1 = ru.initial_recommender(df_videos_cleaned_v10)

# %%
df_videos_recs_test1
# Out:
#          Video_ID                                              Title  \
# 1120  5MBalQDK5IA  FUNDAMENTAL IN VALUE INVESTING - Economic Moat...
# 1089  OHCpUcerz1Q  Economic Moat (Competitive Advantage): Warren ...
# 1116  7MCuwYTTdxE   YIS Unit 3: Lesson 2 - Whatever Floats Your Moat
# 1150  sHhlvdjiY2g      How Do Economic Moats Add Value? (It Matters)
# 1043  AZQVEJh22ZA                          What is an Economic Moat?
#
#      Upload Date   Duration        Views Number of Likes  \
# 1120  2020-05-26   8.433333     No views               0
# 1089  2020-11-22  14.816667     53 views               2
# 1116  2019-09-02  18.333333    202 views               4
# 1150  2020-06-24   7.933333     26 views               0
# 1043  2020-02-20   4.900000  1,947 views              37
#
#                                             Description  \
# 1120  Investing is only complex when you are not wel...
# 1089  What is an Economic Moat and how does an inves...
# 1116  Join the largest High School Investing organiz...
# 1150  What is Economic Moat? Where did the term come...
# 1043  Morningstar's Alex Morozov reveals how Warren ...
#
#                                              Transcript           Topic  \
# 1120  [(welcome, NOUN), (module, PROPN), (module, PR...  Economic Moats
# 1089  [(people, NOUN), (prefer, VERB), (buy, VERB), ...  Economic Moats
# 1116  [(music, NOUN), (welcome, VERB), (young, ADJ),...  Economic Moats
# 1150  [(today, NOUN), (gon, VERB), (na, PROPN), (tal...  Economic Moats
# 1043  [(music, NOUN), (welcome, NOUN), (morningstar,...  Economic Moats
#
#       Topic Coefficient  Months Since Upload
# 1120              0.338             9.928767
# 1089              0.335             4.010959
# 1116              0.333            18.706849
# 1150              0.313             8.975342
# 1043              0.311            13.084932

# %%
df_videos_cleaned_v10 = pu.remove_pos(df_videos_cleaned_v10)

# %%
df_videos_cleaned_v10.to_csv('../App/df_videos_cleaned_v10.csv',index=False)

# %% [markdown]
# ### Follow-up content-based recommender (after the initial knowledge-based recommender takes care of the cold start problem)

# %% [markdown]
# #### TfidfVectorizer, Cosine similarity

# %%
X_tfidf_cosine = ru.follow_up_recommender(df_videos_recs_test1['Video_ID'].iloc[0], df_videos_filtered_test1, TfidfVectorizer, cosine_similarity)
X_tfidf_cosine
# Out:
#        Video_ID                                              Title  \
# 24  F18O45yBtZQ  FUNDAMENTAL IN VALUE INVESTING - Economic Moat...
# 16  dZItart8asY                          What Is An Economic Moat?
# 12  Z9H162gzzCg  Market Beating Stocks With Economic Moats (Com...
# 17  JgHWx_-_4K0  What is an Economic Moat? | Warren Buffett & C...
# 30  EC2AdtkgQNE  WARREN BUFFET'S INVESTMENT STRATEGY: How to Fi...
#
#    Upload Date   Duration        Views Number of Likes  \
# 24  2020-05-29   9.783333     No views               0
# 16  2020-11-20   7.416667     20 views               4
# 12  2020-09-24  10.483333  3,528 views             146
# 17  2020-07-28   5.916667    314 views              19
# 30  2021-02-16  10.066667     60 views              10
#
#                                           Description  \
# 24  Investing is only complex when you are not wel...
# 16  Be More Productive: https://skl.sh/33u3Qbl Kno...
# 12  One of the most important things we look for i...
# 17  "The term economic moat, popularized by Warren...
# 30  Want to improve your investing knowledge? You'...
#
#                                            Transcript           Topic  \
# 24  [(cost, NOUN), (advantage, NOUN), (company, NO...  Economic Moats
# 16  [(economic, ADJ), (mode, NOUN), (longterm, PRO...  Economic Moats
# 12  [(important, ADJ), (thing, NOUN), (look, VERB)...  Economic Moats
# 17  [(hello, INTJ), (welcome, VERB), (financial, A...  Economic Moats
# 30  [(everybody, PRON), (welcome, VERB), (invests,...  Economic Moats
#
#     Topic Coefficient  Months Since Upload
# 24              0.206             9.830137
# 16              0.235             4.076712
# 12              0.253             5.950685
# 17              0.229             7.857534
# 30              0.184             1.183562

# %% [markdown]
# #### TfidfVectorizer, Euclidean distance

# %%
X_tfidf_euclidean = ru.follow_up_recommender(df_videos_recs_test1['Video_ID'].iloc[0], df_videos_filtered_test1, TfidfVectorizer, euclidean_distances)
X_tfidf_euclidean
# Out:
#        Video_ID                                              Title  \
# 62  gdAKtVYELTs  Mohnish Pabrai on how cloning is not in confli...
# 52  wWjv2bIKYDQ  What are MOATS in business? - Tushar Kansal | ...
# 64  gFN5F_BXDmc             economic moat | Tamil | Sharegurutamil
# 35  ozrk3Q_vUvU  Charlie Munger on Traditional Moats. | [C:C.M ...
# 65  SSqhCAgUacQ  Warren Buffet: Durable Competitive Advantage (...
#
#    Upload Date  Duration        Views Number of Likes  \
# 62  2020-07-07  3.283333    965 views              32
# 52  2020-12-21  3.933333      5 views               0
# 64  2019-08-25  9.200000     73 views               5
# 35  2020-06-23  1.666667  2,787 views              72
# 65  2020-09-23  7.166667    132 views              15
#
#                                           Description  \
# 62  [Join YAPSS Membership, For Early Access to Ne...
# 52  What are MOATS in business?\n\nEnjoyed the Vid...
# 64  Economic moat video describes about a company'...
# 35  In this episode, Charlie Munger was asked that...
# 65  Enjoyed this video? \n\nCheck out more videos\...
#
#                                            Transcript           Topic  \
# 62  [(music, PROPN), (buffett, PROPN), (buffett, P...  Economic Moats
# 52  [(music, NOUN), (modes, VERB), (business, NOUN...  Economic Moats
# 64  [(come, VERB), (listen, VERB), (video, PROPN),...  Economic Moats
# 35  [(music, NOUN), (common, ADJ), (sentiment, NOU...  Economic Moats
# 65  [(music, PROPN), (video, PROPN), (warren, PROP...  Economic Moats
#
#     Topic Coefficient  Months Since Upload
# 62              0.039             8.547945
# 52              0.095             3.057534
# 64              0.000            18.969863
# 35              0.156             9.008219
# 65              0.000             5.983562

# %% [markdown]
# #### CountVectorizer, Cosine similarity

# %%
X_cv_cosine = ru.follow_up_recommender(df_videos_recs_test1['Video_ID'].iloc[0], df_videos_filtered_test1, CountVectorizer, cosine_similarity)
X_cv_cosine
# Out:
#        Video_ID                                              Title  \
# 16  dZItart8asY                          What Is An Economic Moat?
# 12  Z9H162gzzCg  Market Beating Stocks With Economic Moats (Com...
# 24  F18O45yBtZQ  FUNDAMENTAL IN VALUE INVESTING - Economic Moat...
# 17  JgHWx_-_4K0  What is an Economic Moat? | Warren Buffett & C...
# 21  s37ifMv5894  What is Economic Moat? | Warren Buffett Invest...
#
#    Upload Date   Duration        Views Number of Likes  \
# 16  2020-11-20   7.416667     20 views               4
# 12  2020-09-24  10.483333  3,528 views             146
# 24  2020-05-29   9.783333     No views               0
# 17  2020-07-28   5.916667    314 views              19
# 21  2020-10-16   4.933333    392 views              30
#
#                                           Description  \
# 16  Be More Productive: https://skl.sh/33u3Qbl Kno...
# 12  One of the most important things we look for i...
# 24  Investing is only complex when you are not wel...
# 17  "The term economic moat, popularized by Warren...
# 21  Hello everyone. Warren Buffett believes that i...
#
#                                            Transcript           Topic  \
# 16  [(economic, ADJ), (mode, NOUN), (longterm, PRO...  Economic Moats
# 12  [(important, ADJ), (thing, NOUN), (look, VERB)...  Economic Moats
# 24  [(cost, NOUN), (advantage, NOUN), (company, NO...  Economic Moats
# 17  [(hello, INTJ), (welcome, VERB), (financial, A...  Economic Moats
# 21  [(hello, INTJ), (welcome, ADJ), (channel, NOUN...  Economic Moats
#
#     Topic Coefficient  Months Since Upload
# 16              0.235             4.076712
# 12              0.253             5.950685
# 24              0.206             9.830137
# 17              0.229             7.857534
# 21              0.213             5.227397

# %% [markdown]
# #### CountVectorizer, Euclidean distance

# %%
X_cv_euclidean = ru.follow_up_recommender(df_videos_recs_test1['Video_ID'].iloc[0], df_videos_filtered_test1, CountVectorizer, euclidean_distances)
X_cv_euclidean
# Out:
#        Video_ID                                              Title  \
# 61  cOlPoEAnN6E  How To Pick Dividend Growth Stocks With Good a...
# 59  a7-LRi-x4B8                      Step 2: Moat (Cost Advantage)
# 46  2creBZPaizI  Warren Buffett's Wonderful Companies: Strong E...
# 6   _WpbrpYjvHk         Investing Basics: Economic Moats Explained
# 18  5Ibc6lE1_aE               Competitive Stock Advantages - MOATS
#
#    Upload Date   Duration        Views Number of Likes  \
# 61  2020-05-21  14.850000  4,297 views             310
# 59  2020-08-25   8.600000      2 views               1
# 46  2020-07-14  15.266667    583 views              33
# 6   2020-11-15  17.633333     58 views               5
# 18  2019-12-28  10.700000    242 views              23
#
#                                           Description  \
# 61  In this video, I want to share with my step by...
# 59  🔥 Step 2: Moat (Cost Advantage) 🔥  \n\nThe 2nd...
# 46  Charlie Tian lays down Warren Buffett's fairly...
# 6   In this video I explain the investing basics o...
# 18  😄Get free investing books and help support the...
#
#                                            Transcript           Topic  \
# 61  [(pick, VERB), (dividend, NOUN), (growth, NOUN...  Economic Moats
# 59  [(welcome, NOUN), (today, NOUN), (video, PROPN...  Economic Moats
# 46  [(fellow, ADJ), (investor, NOUN), (charlie, PR...  Economic Moats
# 6   [(welcome, ADJ), (financial, ADJ), (interest, ...  Economic Moats
# 18  [(idea, PROPN), (traditional, ADJ), (moat, PRO...  Economic Moats
#
#     Topic Coefficient  Months Since Upload
# 61              0.046            10.093151
# 59              0.056             6.936986
# 46              0.123             8.317808
# 6               0.284             4.241096
# 18              0.224            14.860274

# %% [markdown]
# #### *Conclusion: Using CountVectorizer and cosine similarity gives the best recommendations, based on my domain knowledge in stock investing.  Tfidf and CV produce similar results for cosine similarity, but Tfidf gets slightly better results in terms of topic relevance*
