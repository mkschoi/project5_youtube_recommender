# %%
import numpy as np
import pandas as pd
import pickle
from datetime import date
from IPython.display import clear_output

from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %load_ext autoreload
# %autoreload 2

# %%
df_videos_cleaned_v9 = pickle.load(open('../Data/df_videos_cleaned_v9.pickle', 'rb'))

# %% [markdown]
# ### All the functions (Need to put these into a separate .py file)

# %%
def initial_recommender(df):
    '''
    Input: Final dataframe of video data, user input on topic, duration, and upload date
    Output: Top five recommendations
    '''
    ## Take user inputs
    print('Which topics would you like to learn about?')
    topic = input().title()
    
    print('\n')
    print('What is the upper limit of the duration of videos (in minutes)?')
    duration = int(input())
    
    print('\n')
    print('How recent do you want the videos to be (in months since upload date)?')
    upload_date = int(input())
    today = date.today()
    df['Months Since Upload'] = df['Upload Date'].apply(lambda x:((today - x).days)*12/365)

    clear_output()
    
    ## Define a new variable to store the preferred videos. Copy the contents of df to filtered videos
    df_videos_filtered = df.copy()

    ## Return top five videos based on topic coefficient (how relevant the videos are to the user's topic)
    df_videos_filtered = df_videos_filtered[(df_videos_filtered['Topic']==topic) & 
                                      (df_videos_filtered['Duration']<duration) &
                                      (df_videos_filtered['Months Since Upload']<upload_date)]
    df_videos_filtered = df_videos_filtered.sort_values('Topic Coefficient', ascending=False)
    
    return df_videos_filtered.head(), df_videos_filtered

# %%
def follow_up_recommender(video_id, df_videos_filtered, vectorizer, similarity_metric):
    '''
    Input: Video ID of a user's liked video, and the dataframe of the filtered videos generated from the initial recommender
    Output: Top five follow-up recommendations using content-based recommender system
    '''
    ## Fit and transform the transcript into a document-term matrix
    word_list = [[word[0] for word in doc] for doc in df_videos_filtered['Transcript']]
    vec = vectorizer(tokenizer=lambda doc:doc, lowercase=False)
    matrix = vec.fit_transform(word_list).toarray()
    
    ## Generate a similarity matrix
    similarity_matrix = similarity_metric(matrix, matrix)
    
    ## Create a series of indices for the videos (rows)  
    df_videos_filtered = df_videos_filtered.reset_index(drop=True)
    indices = pd.Series(df_videos_filtered['Video_ID'])
    
    ## Get the index of the user's liked video
    idx = indices[indices == video_id].index[0]
    
    ## Create a series with the similarity scores in descending order and grab indices
    score_series = pd.Series(similarity_matrix[idx]).sort_values(ascending=False)
    similarity_indices = list(score_series.index)
    
    ## Drop videos that were in the original recommendation
    similarity_indices = [index for index in similarity_indices if index not in list(df_videos_filtered[:5].index)]
    top_5_indices = similarity_indices[:5]
    
    ## Populate a dataframe of the recommended videos
    df_videos_follow_up_recs = df_videos_filtered.iloc[top_5_indices]
    
    return df_videos_follow_up_recs

# %% [markdown]
# ### Initial knowledge-based recommender

# %%
df_videos_recs_test1, df_videos_filtered_test1 = initial_recommender(df_videos_cleaned_v9)

# %%
df_videos_recs_test1
# Out:
#          Video_ID                                              Title  \
# 989   i7WDGREdwlM  Is Value Investing Outdated? | Reaction to @Ch...
# 178   nN861I9nLJM  How can you invest like Warren Buffett? What i...
# 1220  _sYnjYPFNgw          LONG TERM STOCK MARKET INVESTING FOR 2020
# 986   X-3KpqHr_kY        Is Warren Buffett's 'Value Investing' Dead?
# 1248  eXg3kvWJsDE  HOW DO FUND MANAGERS PICK STOCKS FOR LONG TERM...
#
#      Upload Date   Duration         Views Number of Likes  \
# 989   2020-05-14  28.116667   3,332 views             216
# 178   2020-11-08  20.416667      16 views               3
# 1220  2020-05-06  29.683333  10,617 views             533
# 986   2020-06-03  17.016667  32,316 views             865
# 1248  2020-06-28  22.116667  16,213 views             520
#
#                                             Description  \
# 989   Follow me on Instagram:\nhttps://www.instagram...
# 178   GRAB MY FREE KNOW WHERE TO INVEST REPORT!  CLI...
# 1220  LONG TERM STOCK MARKET INVESTING FOR 2020\n\nH...
# 986   Is value investing dead? Ben Graham, and now W...
# 1248  HOW DO FUND MANAGERS PICK STOCKS FOR LONG TERM...
#
#                                              Transcript    Topic  \
# 989   [(hey, INTJ), (tom, PROPN), (invest, VERB), (t...  General
# 178   [(hello, INTJ), (welcome, INTJ), (know, VERB),...  General
# 1220  [(hi, INTJ), (video, PROPN), (gon, NOUN), (na,...  General
# 986   [(hey, INTJ), (welcome, NOUN), (channel, NOUN)...  General
# 1248  [(look, VERB), (history, NOUN), (philippine, A...  General
#
#       Topic Coefficient  Months Since Upload
# 989               0.120             9.994521
# 178               0.114             4.142466
# 1220              0.112            10.257534
# 986               0.105             9.336986
# 1248              0.105             8.515068

# %%
df_videos_cleaned_v9.to_csv('../App/df_videos_cleaned_v9.csv',index=False)

# %% [markdown]
# ### Follow-up content-based recommender (after the initial knowledge-based recommender takes care of the cold start problem)

# %% [markdown]
# #### TfidfVectorizer, Cosine similarity

# %%
X_tfidf_cosine = follow_up_recommender('nN861I9nLJM', df_videos_filtered_test1, TfidfVectorizer, cosine_similarity)
X_tfidf_cosine
# Out:
#         Video_ID                                              Title  \
# 29   VbTX_WQaYkU                            What is Value Investing
# 10   K4EVbLmQjfY  What's the difference between Trading and Inve...
# 124  yTqOuLH3Qpw  061 Understanding Technical Analysis And Funda...
# 27   MIR3BXUtrak  Why Growth Investing Is Harder Than You Think ...
# 146  0J0E5Ki0gBA  WHAT IS VALUE INVESTING? | The Art of Value In...
#
#     Upload Date   Duration      Views Number of Likes  \
# 29   2020-09-07  14.783333  262 views              20
# 10   2020-09-03   6.433333  192 views              14
# 124  2020-09-12  11.116667   16 views               0
# 27   2020-10-18  19.383333  206 views              12
# 146  2020-06-08   5.750000  338 views              20
#
#                                            Description  \
# 29   What is Value Investing?\n\n🔬Join my INVESTMEN...
# 10   Welcome back! \n\nThe most common question ask...
# 124  BEST Investing APP https://m1.finance/P_U-E2g_...
# 27   Growth investing has seemed easy in the past d...
# 146  Subscribe to my channel! https://bit.ly/subscr...
#
#                                             Transcript    Topic  \
# 29   [(video, PROPN), (value, NOUN), (invest, VERB)...  General
# 10   [(music, NOUN), (welcome, NOUN), (video, PROPN...  General
# 124  [(invest, VERB), (stock, NOUN), (market, NOUN)...  General
# 27   [(welcome, INTJ), (return, NOUN), (focus, NOUN...  General
# 146  [(look, VERB), (find, VERB), (value, NOUN), (i...  General
#
#      Topic Coefficient  Months Since Upload
# 29               0.086             6.180822
# 10               0.096             6.312329
# 124              0.060             6.016438
# 27               0.086             4.832877
# 146              0.057             9.172603

# %% [markdown]
# #### TfidfVectorizer, Euclidean distance

# %%
X_tfidf_euclidean = follow_up_recommender('nN861I9nLJM', df_videos_filtered_test1, TfidfVectorizer, euclidean_distances)
X_tfidf_euclidean
# Out:
#         Video_ID                                              Title  \
# 310  c9NEhHYC53E  Havells India Ltd. | Fundamental Analysis | #S...
# 315  dBb_pbQwULo  How to select a stock for investing | Introduc...
# 314  rtxSDyASUKQ  UNBOXING | The Intelligent Investor: The Defin...
# 312  nMPkvDLU0yg  Fundamental vs. Technical Analysis: Which One ...
# 300  TLYJ8_EApnk  BRITANNIA Stock fundamental and technical anal...
#
#     Upload Date  Duration     Views Number of Likes  \
# 310  2020-09-19  1.933333  41 views               6
# 315  2021-01-20  5.750000  42 views               7
# 314  2021-03-03  1.466667  11 views               1
# 312  2020-07-04  6.850000  29 views               1
# 300  2021-02-27  9.100000  87 views               4
#
#                                            Description  \
# 310  A Small Initiative to make awareness in share ...
# 315  This video tells you the process of stock sele...
# 314  FULL TITLE: The Intelligent Investor: The Defi...
# 312  Most beginner investors ask the best way to pi...
# 300  Welcome to our youtube channel "earn with stoc...
#
#                                             Transcript    Topic  \
# 310  [(music, NOUN), (music, NOUN), (applause, NOUN...  General
# 315      [(music, NOUN), (music, NOUN), (music, NOUN)]  General
# 314  [(music, NOUN), (music, NOUN), (music, NOUN), ...  General
# 312  [(music, NOUN), (applause, NOUN), (music, NOUN...  General
# 300  [(music, NOUN), (music, NOUN), (foreign, ADJ),...  General
#
#      Topic Coefficient  Months Since Upload
# 310              0.004             5.786301
# 315              0.000             1.742466
# 314              0.000             0.361644
# 312              0.004             8.317808
# 300              0.011             0.493151

# %% [markdown]
# #### CountVectorizer, Cosine similarity

# %%
X_cv_cosine = follow_up_recommender('nN861I9nLJM', df_videos_filtered_test1, CountVectorizer, cosine_similarity)
X_cv_cosine
# Out:
#         Video_ID                                              Title  \
# 86   yBNi5fYMIfM  Are these stocks undervalued? | Warren Buffett...
# 159  K_15cfTklu0  Multibagger Stocks - Must Buy Stocks For 2021 ...
# 124  yTqOuLH3Qpw  061 Understanding Technical Analysis And Funda...
# 146  0J0E5Ki0gBA  WHAT IS VALUE INVESTING? | The Art of Value In...
# 24   tad2l_wwnGM  Peter Lynch: How To Invest With Stocks At High...
#
#     Upload Date   Duration          Views Number of Likes  \
# 86   2020-03-31  17.116667      173 views               7
# 159  2020-11-18  18.283333   44,429 views             870
# 124  2020-09-12  11.116667       16 views               0
# 146  2020-06-08   5.750000      338 views              20
# 24   2021-01-09   2.066667  222,284 views              5K
#
#                                            Description  \
# 86   In today's episode of StockerFinance we talk a...
# 159  Join the channel Membership To Get Access To M...
# 124  BEST Investing APP https://m1.finance/P_U-E2g_...
# 146  Subscribe to my channel! https://bit.ly/subscr...
# 24   In this video Peter Lynch discusses how to inv...
#
#                                             Transcript    Topic  \
# 86   [(modern, PROPN), (warren, PROPN), (buffett, P...  General
# 159  [(music, NOUN), (hello, INTJ), (friends, NOUN)...  General
# 124  [(invest, VERB), (stock, NOUN), (market, NOUN)...  General
# 146  [(look, VERB), (find, VERB), (value, NOUN), (i...  General
# 24   [(peter, PROPN), (lynch, PROPN), (smart, ADJ),...  General
#
#      Topic Coefficient  Months Since Upload
# 86               0.069            11.441096
# 159              0.055             3.813699
# 124              0.060             6.016438
# 146              0.057             9.172603
# 24               0.087             2.104110

# %% [markdown]
# #### CountVectorizer, Euclidean distance

# %%
X_cv_euclidean = follow_up_recommender('nN861I9nLJM', df_videos_filtered_test1, CountVectorizer, euclidean_distances)
X_cv_euclidean
# Out:
#         Video_ID                                              Title  \
# 14   zqgRCerwSfQ  Free Cash Flow Plus Growth: Reverse Engineerin...
# 22   9sWecuhjzOI  My March 2021 BNPL Game Plan For ZIP, Afterpay...
# 15   VIFBMx3VLx4  From trading on Emotions to Fundamental Invest...
# 277  uEclt5D59hw  Dividend Growth Investing - The Power of Compo...
# 114  cH2You1fy0k  Top 5 BANK Stocks to Watch! - Q2 Analysis 2020...
#
#     Upload Date   Duration         Views Number of Likes  \
# 14   2020-11-03   5.666667   1,844 views              72
# 22   2021-03-03   2.750000   5,247 views             190
# 15   2021-02-26  20.633333       6 views               0
# 277  2020-11-16  22.150000   1,005 views              54
# 114  2020-06-07  23.800000  20,056 views              1K
#
#                                            Description  \
# 14   QuickFS Link: https://quickfs.net/?via=focused...
# 22   In this video I unpack my March 2021 game plan...
# 15   I first started investing back in 2017. It was...
# 277  This video shows how the power of compounding ...
# 114  What are the top 5 bank stocks to watch in 202...
#
#                                             Transcript    Topic  \
# 14   [(music, NOUN), (welcome, ADJ), (welcome, ADJ)...  General
# 22   [(hey, INTJ), (welcome, INTJ), (phil, ADJ), (m...  General
# 15   [(right, INTJ), (folk, NOUN), (member, NOUN), ...  General
# 277  [(hello, INTJ), (today, NOUN), (video, PROPN),...  General
# 114  [(hey, INTJ), (saver, PROPN), (investor, NOUN)...  General
#
#      Topic Coefficient  Months Since Upload
# 14               0.094             4.306849
# 22               0.088             0.361644
# 15               0.094             0.526027
# 277              0.031             3.879452
# 114              0.062             9.205479

# %% [markdown]
# #### *Conclusion: Using TfidfVectorizer and cosine similarity gives the best recommendations, based on my domain knowledge in stock investing.  Tfidf and CV produce similar results for cosine similarity, but Tfidf gets slightly better results in terms of topic relevance*
