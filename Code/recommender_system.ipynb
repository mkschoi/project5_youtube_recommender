# %%
import numpy as np
import pandas as pd
import pickle
from datetime import date
from IPython.display import clear_output

from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %load_ext autoreload
# %autoreload 2

# %%
df_videos_cleaned_v9 = pickle.load(open('../Data/df_videos_cleaned_v9.pickle', 'rb'))

# %% [markdown]
# ### All the functions (Need to put these into a separate .py file)

# %%
def initial_recommender(df):
    '''
    Input: Final dataframe of video data, user input on topic, duration, and upload date
    Output: Top five recommendations
    '''
    ## Take user inputs
    print('Which topics would you like to learn about?')
    topic = input().title()
    
    print('\n')
    print('What is the upper limit of the duration of videos (in minutes)?')
    duration = int(input())
    
    print('\n')
    print('How recent do you want the videos to be (in months since upload date)?')
    upload_date = int(input())
    today = date.today()
    df['Months Since Upload'] = df['Upload Date'].apply(lambda x:((today - x).days)*12/365)

    clear_output()
    
    ## Define a new variable to store the preferred videos. Copy the contents of df to filtered videos
    df_videos_filtered = df.copy()

    ## Return top five videos based on topic coefficient (how relevant the videos are to the user's topic)
    df_videos_filtered = df_videos_filtered[(df_videos_filtered['Topic']==topic) & 
                                      (df_videos_filtered['Duration']<duration) &
                                      (df_videos_filtered['Months Since Upload']<upload_date)]
    df_videos_filtered = df_videos_filtered.sort_values('Topic Coefficient', ascending=False)
    
    return df_videos_filtered.head(), df_videos_filtered

# %%
def follow_up_recommender(video_id, df_videos_filtered, vectorizer, similarity_metric):
    '''
    Input: Video ID of a user's liked video, and the dataframe of the filtered videos generated from the initial recommender
    Output: Top five follow-up recommendations using content-based recommender system
    '''
    ## Fit and transform the transcript into a document-term matrix
    word_list = [[word[0] for word in doc] for doc in df_videos_filtered['Transcript']]
    vec = vectorizer(tokenizer=lambda doc:doc, lowercase=False)
    matrix = vec.fit_transform(word_list).toarray()
    
    ## Generate a similarity matrix
    similarity_matrix = similarity_metric(matrix, matrix)
    
    ## Create a series of indices for the videos (rows)  
    df_videos_filtered = df_videos_filtered.reset_index(drop=True)
    indices = pd.Series(df_videos_filtered['Video_ID'])
    
    ## Get the index of the user's liked video
    idx = indices[indices == video_id].index[0]
    
    ## Create a series with the similarity scores in descending order and grab indices
    score_series = pd.Series(similarity_matrix[idx]).sort_values(ascending=False)
    similarity_indices = list(score_series.index)
    
    ## Drop videos that were in the original recommendation
    similarity_indices = [index for index in similarity_indices if index not in list(df_videos_filtered[:5].index)]
    top_5_indices = similarity_indices[:5]
    
    ## Populate a dataframe of the recommended videos
    df_videos_follow_up_recs = df_videos_filtered.iloc[top_5_indices]
    
    return df_videos_follow_up_recs

# %% [markdown]
# ### Initial knowledge-based recommender

# %%
df_videos_recs_test1, df_videos_filtered_test1 = initial_recommender(df_videos_cleaned_v9)

# %%
df_videos_recs_test1
# Out:
#         Video_ID                                              Title  \
# 357  7MCuwYTTdxE   YIS Unit 3: Lesson 2 - Whatever Floats Your Moat
# 324  OHCpUcerz1Q  Economic Moat (Competitive Advantage): Warren ...
# 362  5MBalQDK5IA  FUNDAMENTAL IN VALUE INVESTING - Economic Moat...
# 264  foiHBYfld2c  How to Pick a Strong Moat | Economic Moats Exp...
# 325  WQiX7a_z--4               The Morningstar Economic Moat Rating
#
#     Upload Date   Duration        Views Number of Likes  \
# 357  2019-09-02  18.333333    202 views               4
# 324  2020-11-22  14.816667     53 views               2
# 362  2020-05-26   8.433333     No views               0
# 264  2018-12-10  12.483333  3,024 views             141
# 325  2016-05-02   1.616667    499 views               2
#
#                                            Description  \
# 357  Join the largest High School Investing organiz...
# 324  What is an Economic Moat and how does an inves...
# 362  Investing is only complex when you are not wel...
# 264  ★ ★ MY COURSES ★ ★\n\nStock Market Investing f...
# 325  The Morningstar Economic Moat Rating represent...
#
#                                             Transcript              Topic  \
# 357  [(music, NOUN), (welcome, VERB), (young, ADJ),...  Competitive Moats
# 324  [(people, NOUN), (prefer, VERB), (buy, VERB), ...  Competitive Moats
# 362  [(hey, INTJ), (welcome, NOUN), (module, PROPN)...  Competitive Moats
# 264  [(hey, INTJ), (welcome, VERB), (ozzie, PROPN),...  Competitive Moats
# 325  [(morningstar, PROPN), (economic, ADJ), (moat,...  Competitive Moats
#
#      Topic Coefficient  Months Since Upload
# 357              0.338            18.312329
# 324              0.336             3.616438
# 362              0.335             9.534247
# 264              0.326            27.057534
# 325              0.322            58.356164

# %%
df_videos_cleaned_v9.to_csv('../App/df_videos_cleaned_v9.csv',index=False)

# %% [markdown]
# ### Follow-up content-based recommender (after the initial knowledge-based recommender takes care of the cold start problem)

# %% [markdown]
# #### TfidfVectorizer, Cosine similarity

# %%
X_tfidf_cosine = follow_up_recommender('OHCpUcerz1Q', df_videos_filtered_test1, TfidfVectorizer, cosine_similarity)
X_tfidf_cosine
# Out:
#        Video_ID                                              Title  \
# 14  IA-dcUF5HL0                          What is an Economic MOAT?
# 20  thckfWlaVcQ        How to Pick a Stock to Buy - Part 2 - Moats
# 7   sHhlvdjiY2g      How Do Economic Moats Add Value? (It Matters)
# 12  kz4m-Q-Zpp8  Economic Moats To Look For - Investing Warren ...
# 36  F18O45yBtZQ  FUNDAMENTAL IN VALUE INVESTING - Economic Moat...
#
#    Upload Date  Duration        Views Number of Likes  \
# 14  2020-09-16  3.933333     15 views               1
# 20  2019-04-22  5.533333    752 views              37
# 7   2020-06-24  7.933333     26 views               0
# 12  2018-02-18  2.016667  2,131 views              79
# 36  2020-05-29  9.783333     No views               0
#
#                                           Description  \
# 14  How to quickly identify a companies economic m...
# 20  Moats are competitive advantages that a compan...
# 7   What is Economic Moat? Where did the term come...
# 12  In this video I talk about the key ingredient ...
# 36  Investing is only complex when you are not wel...
#
#                                            Transcript              Topic  \
# 14  [(today, NOUN), (video, PROPN), (teach, AUX), ...  Competitive Moats
# 20  [(hello, INTJ), (welcome, ADJ), (channel, NOUN...  Competitive Moats
# 7   [(today, NOUN), (gon, VERB), (na, PROPN), (tal...  Competitive Moats
# 12  [(hey, INTJ), (welcome, VERB), (ozzie, NOUN), ...  Competitive Moats
# 36  [(cost, NOUN), (advantage, NOUN), (company, NO...  Competitive Moats
#
#     Topic Coefficient  Months Since Upload
# 14              0.282             5.819178
# 20              0.257            22.684932
# 7               0.317             8.580822
# 12              0.294            36.756164
# 36              0.208             9.435616

# %% [markdown]
# #### TfidfVectorizer, Euclidean distance

# %%
X_tfidf_euclidean = follow_up_recommender('OHCpUcerz1Q', df_videos_filtered_test1, TfidfVectorizer, euclidean_distances)
X_tfidf_euclidean
# Out:
#         Video_ID                                              Title  \
# 98   -NllUDR8b-M                                Coca Cola's 5 moats
# 58   ozrk3Q_vUvU  Charlie Munger on Traditional Moats. | [C:C.M ...
# 69   BH5TnaczIvw  Warren Buffett vs Elon Musk: Moat Building or ...
# 102  gdAKtVYELTs  Mohnish Pabrai on how cloning is not in confli...
# 88   ZYh3Y9LXoNo  Warren Buffett: What is a Moat and Why is it I...
#
#     Upload Date  Duration        Views Number of Likes  \
# 98   2016-07-26  4.433333  1,376 views              14
# 58   2020-06-23  1.666667  2,787 views              72
# 69   2018-07-31  2.000000  1,501 views               9
# 102  2020-07-07  4.333333    965 views              32
# 88   2020-05-03  7.216667     25 views               0
#
#                                            Description  \
# 98          This episode explores Coca Cola's 5 moats.
# 58   In this episode, Charlie Munger was asked that...
# 69   (May 5, 2018) Warren #Buffett and Charlie #Mun...
# 102  [Join YAPSS Membership, For Early Access to Ne...
# 88   Warren Buffett is an American investor, busine...
#
#                                             Transcript              Topic  \
# 98   [(wanted, ADJ), (business, NOUN), (moat, PROPN...  Competitive Moats
# 58   [(music, NOUN), (common, ADJ), (sentiment, NOU...  Competitive Moats
# 69   [(elon, NOUN), (musk, NOUN), (week, NOUN), (te...  Competitive Moats
# 102  [(music, PROPN), (buffett, PROPN), (buffett, P...  Competitive Moats
# 88   [(area, NOUN), (work, NOUN), (good, ADJ), (mor...  Competitive Moats
#
#      Topic Coefficient  Months Since Upload
# 98               0.055            55.561644
# 58               0.157             8.613699
# 69               0.126            31.397260
# 102              0.040             8.153425
# 88               0.069            10.290411

# %% [markdown]
# #### CountVectorizer, Cosine similarity

# %%
X_cv_cosine = follow_up_recommender('OHCpUcerz1Q', df_videos_filtered_test1, CountVectorizer, cosine_similarity)
X_cv_cosine
# Out:
#        Video_ID                                              Title  \
# 14  IA-dcUF5HL0                          What is an Economic MOAT?
# 7   sHhlvdjiY2g      How Do Economic Moats Add Value? (It Matters)
# 12  kz4m-Q-Zpp8  Economic Moats To Look For - Investing Warren ...
# 31  GDgQBwQBaI8  5 Economic Moats in the Stock Market📈 | Why Mo...
# 15  mUI912y74GY  How to Identify an Economic Moat - Low Risk St...
#
#    Upload Date  Duration        Views Number of Likes  \
# 14  2020-09-16  3.933333     15 views               1
# 7   2020-06-24  7.933333     26 views               0
# 12  2018-02-18  2.016667  2,131 views              79
# 31  2017-09-13  5.966667    873 views              40
# 15  2018-02-06  6.250000  2,027 views              83
#
#                                           Description  \
# 14  How to quickly identify a companies economic m...
# 7   What is Economic Moat? Where did the term come...
# 12  In this video I talk about the key ingredient ...
# 31  SUBSCRIBE: http://bit.ly/FinancialinfoYT \nRob...
# 15  Do you want to know for sure if a business is ...
#
#                                            Transcript              Topic  \
# 14  [(today, NOUN), (video, PROPN), (teach, AUX), ...  Competitive Moats
# 7   [(today, NOUN), (gon, VERB), (na, PROPN), (tal...  Competitive Moats
# 12  [(hey, INTJ), (welcome, VERB), (ozzie, NOUN), ...  Competitive Moats
# 31  [(upbeat, ADJ), (music, NOUN), (hello, INTJ), ...  Competitive Moats
# 15  [(hey, INTJ), (hamish, PROPN), (buddy, NOUN), ...  Competitive Moats
#
#     Topic Coefficient  Months Since Upload
# 14              0.282             5.819178
# 7               0.317             8.580822
# 12              0.294            36.756164
# 31              0.226            41.950685
# 15              0.281            37.150685

# %% [markdown]
# #### CountVectorizer, Euclidean distance

# %%
X_cv_euclidean = follow_up_recommender('OHCpUcerz1Q', df_videos_filtered_test1, CountVectorizer, euclidean_distances)
X_cv_euclidean
# Out:
#        Video_ID                                              Title  \
# 90  KVncb-LuVSU     Dividend Growth Investing: How I Select Stocks
# 9   fYacJ2Hz7BA  Dividend growth investing in companies with an...
# 86  Uul7NnPCIk4  Long Term Investing! Modern Day Long Term Inve...
# 83  oFB3h1QkfwQ  How to Analyse Business Models! | #1 Cost Adva...
# 84  x090-livIfM          Beginners Guide to Value Investing (2021)
#
#    Upload Date   Duration         Views Number of Likes  \
# 90  2017-04-05  14.516667   5,877 views             178
# 9   2020-01-05   5.666667   4,223 views             182
# 86  2017-01-02  14.983333  70,936 views            1.6K
# 83  2021-02-23  11.450000      31 views               6
# 84  2020-07-10  11.283333     141 views              15
#
#                                           Description  \
# 90  I'm a dividend growth investor building a mach...
# 9   What is an economic moat and why is it importa...
# 86  --~--\nThis video covers Long term investing a...
# 83  H goes through how to use find cost advantage ...
# 84  In this video you will learn what value invest...
#
#                                            Transcript              Topic  \
# 90  [(invest, VERB), (cash, NOUN), (flow, NOUN), (...  Competitive Moats
# 9   [(everybody, PRON), (welcome, VERB), (channel,...  Competitive Moats
# 86  [(longterm, PROPN), (invest, VERB), (strategy,...  Competitive Moats
# 83  [(hey, INTJ), (everybody, PRON), (welcome, VER...  Competitive Moats
# 84  [(today, NOUN), (gon, VERB), (na, PROPN), (dis...  Competitive Moats
#
#     Topic Coefficient  Months Since Upload
# 90              0.065            47.243836
# 9               0.305            14.202740
# 86              0.086            50.301370
# 83              0.097             0.558904
# 84              0.087             8.054795

# %% [markdown]
# #### *Conclusion: Using TfidfVectorizer and cosine similarity gives the best recommendations, based on my domain knowledge in stock investing.  Tfidf and CV produce similar results for cosine similarity, but Tfidf gets slightly better results in terms of topic relevance*
